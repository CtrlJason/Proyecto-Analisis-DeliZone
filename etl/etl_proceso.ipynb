# %% [markdown]
# ### Importamos las librerias

# %%
import pandas as pd

# %% [markdown]
# ### Inicialmente mostramos los datos de las publicaciones

# %%
print("Iniciando proceso ETL de las publicaciones...")
df_origin = pd.read_csv('../data/publicaciones.csv')
df = df_origin.copy()

# Mostramos los datos de las publicaciones
df
# Out:
# Iniciando proceso ETL de las publicaciones...
#    Identificador de la publicación  Identificador de la cuenta  \
# 0                18040576172497692           17841469739624306
# 1                17922958478861686           17841469739624306
# 2                18023774504396308           17841469739624306
# 3                18032498174201318           17841469739624306
# 4                17934766817800552           17841469739624306
# 5                18049272811911405           17841469739624306
#
#   Nombre de usuario de la cuenta Nombre de la cuenta  \
# 0               delizone_oficial            DeliZone
# 1               delizone_oficial            DeliZone
# 2               delizone_oficial            DeliZone
# 3               delizone_oficial            DeliZone
# 4               delizone_oficial            DeliZone
# 5               delizone_oficial            DeliZone
#
#                                          Descripción  Duración (segundos)  \
# 0  ¿Quieres que más clientes te encuentren en lín...                    0
# 1  ⭐ Con nuestras plantillas, podrás: \n✅ Persona...                    0
# 2  Crea la página web de tus sueños en minutos\n\...                    0
# 3  ¿Quieres impulsar el crecimiento de tu negocio...                    0
# 4  "¡Aumenta las ventas de tu restaurante con est...                    0
# 5  ¿Tu restaurante ya tiene presencia en línea?\n...                    0
#
#   Hora de publicación                         Enlace permanente  \
# 0    09/28/2024 14:33  https://www.instagram.com/p/DAed_eBSBhh/
# 1    09/27/2024 11:13  https://www.instagram.com/p/DAbiSWlyex3/
# 2    10/07/2024 15:00  https://www.instagram.com/p/DA1sKcRN8y-/
# 3    10/06/2024 15:00  https://www.instagram.com/p/DAzHXfjN_Zu/
# 4    10/05/2024 19:24  https://www.instagram.com/p/DAxAz42O7b7/
# 5    09/30/2024 07:02  https://www.instagram.com/p/DAiz5m8Omfh/
#
#       Tipo de publicación  Comentario sobre los datos  Fecha  Impresiones  \
# 0  Secuencia de Instagram                         NaN  Total          129
# 1     Imagen de Instagram                         NaN  Total           93
# 2  Secuencia de Instagram                         NaN  Total           63
# 3  Secuencia de Instagram                         NaN  Total           71
# 4  Secuencia de Instagram                         NaN  Total           44
# 5  Secuencia de Instagram                         NaN  Total          344
#
#    Alcance  Me gusta  Veces que se compartió  Comentarios  \
# 0       82        16                       1            0
# 1       74        19                       0            0
# 2       51         2                       0            0
# 3       60         6                       0            0
# 4       35         5                       0            0
# 5      293        57                       2            0
#
#    Veces que se guardó  Seguimientos
# 0                    0           NaN
# 1                    0           1.0
# 2                    0           NaN
# 3                    1           NaN
# 4                    0           NaN
# 5                    2          44.0

# %% [markdown]
# ### Mostramos los tipos de dato de cada columna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Identificador de la publicación  6 non-null      int64
#  1   Identificador de la cuenta       6 non-null      int64
#  2   Nombre de usuario de la cuenta   6 non-null      object
#  3   Nombre de la cuenta              6 non-null      object
#  4   Descripción                      6 non-null      object
#  5   Duración (segundos)              6 non-null      int64
#  6   Hora de publicación              6 non-null      object
#  7   Enlace permanente                6 non-null      object
#  8   Tipo de publicación              6 non-null      object
#  9   Comentario sobre los datos       0 non-null      float64
#  10  Fecha                            6 non-null      object
#  11  Impresiones                      6 non-null      int64
#  12  Alcance                          6 non-null      int64
#  13  Me gusta                         6 non-null      int64
#  14  Veces que se compartió           6 non-null      int64
#  15  Comentarios                      6 non-null      int64
#  16  Veces que se guardó              6 non-null      int64
#  17  Seguimientos                     2 non-null      float64
# dtypes: float64(2), int64(9), object(7)
# memory usage: 996.0+ bytes

# %% [markdown]
# ### Eliminacion de columnas que no son de utilidad

# %%
COLUMNS_TO_DROP = [
    'Identificador de la cuenta',
    'Nombre de usuario de la cuenta',
    'Nombre de la cuenta', 'Duración (segundos)',
    'Comentario sobre los datos',
    'Comentarios',
    'Enlace permanente',
    'Fecha',
]
df = df.drop(COLUMNS_TO_DROP, axis=1)
df
# Out:
#    Identificador de la publicación  \
# 0                18040576172497692
# 1                17922958478861686
# 2                18023774504396308
# 3                18032498174201318
# 4                17934766817800552
# 5                18049272811911405
#
#                                          Descripción Hora de publicación  \
# 0  ¿Quieres que más clientes te encuentren en lín...    09/28/2024 14:33
# 1  ⭐ Con nuestras plantillas, podrás: \n✅ Persona...    09/27/2024 11:13
# 2  Crea la página web de tus sueños en minutos\n\...    10/07/2024 15:00
# 3  ¿Quieres impulsar el crecimiento de tu negocio...    10/06/2024 15:00
# 4  "¡Aumenta las ventas de tu restaurante con est...    10/05/2024 19:24
# 5  ¿Tu restaurante ya tiene presencia en línea?\n...    09/30/2024 07:02
#
#       Tipo de publicación  Impresiones  Alcance  Me gusta  \
# 0  Secuencia de Instagram          129       82        16
# 1     Imagen de Instagram           93       74        19
# 2  Secuencia de Instagram           63       51         2
# 3  Secuencia de Instagram           71       60         6
# 4  Secuencia de Instagram           44       35         5
# 5  Secuencia de Instagram          344      293        57
#
#    Veces que se compartió  Veces que se guardó  Seguimientos
# 0                       1                    0           NaN
# 1                       0                    0           1.0
# 2                       0                    0           NaN
# 3                       0                    1           NaN
# 4                       0                    0           NaN
# 5                       2                    2          44.0

# %% [markdown]
# Separacion de hastags de la descripción

# %%
# Mostramos una de las descripciones para obtener la informacion completa
df.iloc[0]['Descripción']
# Out:
# '¿Quieres que más clientes te encuentren en línea? Aquí te dejamos tres tips para mejorar la presencia digital de tu restaurante:\n\n#restaurantesdigitales \n#marketingrestaurantes \n#webdesign \n#emprendedores \n#menudigital'

# %%
# Ahora obtenemos unicamente los numerales de todas las descripciones
df['Descripción'].str.findall('#')
# se visualizaran todos los # que esten en la descripción
# Out:
# 0             [#, #, #, #, #]
# 1    [#, #, #, #, #, #, #, #]
# 2             [#, #, #, #, #]
# 3                [#, #, #, #]
# 4                   [#, #, #]
# 5             [#, #, #, #, #]
# Name: Descripción, dtype: object

# %%
# Ahora obtenemos los Hashtags completos
df['Descripción'].str.findall(r'#\w+') # findall nos sirve para buscar partes de un string en especifico
# Out:
# 0    [#restaurantesdigitales, #marketingrestaurante...
# 1    [#Restaurantes, #Emprendimiento, #SolucionesDi...
# 2    [#Delizone, #PaginaWeb, #Personalizacion, #Pla...
# 3    [#ventasonline, #negocio, #emprendimiento, #cr...
# 4                    [#ventas, #restaurante, #negocio]
# 5    [#restaurantes, #marketingdigital, #diseñoweb,...
# Name: Descripción, dtype: object

# %%
# Ahora creamos separamos los hastag de la descripcion
df['Hashtags'] = df['Descripción'].str.findall(r'#\w+')
df
# Out:
#    Identificador de la publicación  \
# 0                18040576172497692
# 1                17922958478861686
# 2                18023774504396308
# 3                18032498174201318
# 4                17934766817800552
# 5                18049272811911405
#
#                                          Descripción Hora de publicación  \
# 0  ¿Quieres que más clientes te encuentren en lín...    09/28/2024 14:33
# 1  ⭐ Con nuestras plantillas, podrás: \n✅ Persona...    09/27/2024 11:13
# 2  Crea la página web de tus sueños en minutos\n\...    10/07/2024 15:00
# 3  ¿Quieres impulsar el crecimiento de tu negocio...    10/06/2024 15:00
# 4  "¡Aumenta las ventas de tu restaurante con est...    10/05/2024 19:24
# 5  ¿Tu restaurante ya tiene presencia en línea?\n...    09/30/2024 07:02
#
#       Tipo de publicación  Impresiones  Alcance  Me gusta  \
# 0  Secuencia de Instagram          129       82        16
# 1     Imagen de Instagram           93       74        19
# 2  Secuencia de Instagram           63       51         2
# 3  Secuencia de Instagram           71       60         6
# 4  Secuencia de Instagram           44       35         5
# 5  Secuencia de Instagram          344      293        57
#
#    Veces que se compartió  Veces que se guardó  Seguimientos  \
# 0                       1                    0           NaN
# 1                       0                    0           1.0
# 2                       0                    0           NaN
# 3                       0                    1           NaN
# 4                       0                    0           NaN
# 5                       2                    2          44.0
#
#                                             Hashtags
# 0  [#restaurantesdigitales, #marketingrestaurante...
# 1  [#Restaurantes, #Emprendimiento, #SolucionesDi...
# 2  [#Delizone, #PaginaWeb, #Personalizacion, #Pla...
# 3  [#ventasonline, #negocio, #emprendimiento, #cr...
# 4                  [#ventas, #restaurante, #negocio]
# 5  [#restaurantes, #marketingdigital, #diseñoweb,...
